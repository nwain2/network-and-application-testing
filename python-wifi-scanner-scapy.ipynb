# %%
from scapy.all import *
from threading import Thread
import pandas
import time
import os

# initialize the networks dataframe that will contain all access points nearby
networks = pandas.DataFrame(columns=["BSSID", "SSID", "dBm_Signal", "Channel", "Crypto"])
# set the index BSSID (MAC address of the AP)
networks.set_index("BSSID", inplace=True)

def callback(packet):
    if packet.haslayer(Dot11Beacon):
        # extract the MAC address of the network
        bssid = packet[Dot11].addr2
        # get the name of it
        ssid = packet[Dot11Elt].info.decode()
        try:
            dbm_signal = packet.dBm_AntSignal
        except:
            dbm_signal = "N/A"
        # extract network stats
        stats = packet[Dot11Beacon].network_stats()
        # get the channel of the AP
        channel = stats.get("channel")
        # get the crypto
        crypto = stats.get("crypto")
        networks.loc[bssid] = (ssid, dbm_signal, channel, crypto)


def print_all():
    while True:
        os.system("clear")
        print(networks)
        time.sleep(0.5)


def change_channel():
    ch = 1
    while True:
        os.system(f"iwconfig {interface} channel {ch}")
        # switch channel from 1 to 14 each 0.5s
        ch = ch % 14 + 1
        time.sleep(0.5)


if __name__ == "__main__":
    # interface name, check using iwconfig
    interface = "wlan0mon"
    # start the thread that prints all the networks
    printer = Thread(target=print_all)
    printer.daemon = True
    printer.start()
    # start the channel changer
    channel_changer = Thread(target=change_channel)
    channel_changer.daemon = True
    channel_changer.start()
    # start sniffing
    sniff(prn=callback, iface=interface)
# Out:
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21236\4284717491.py in <module>
#      57     channel_changer.start()
#      58     # start sniffing
# ---> 59     sniff(prn=callback, iface=interface)
#
# ~\anaconda3\lib\site-packages\scapy\sendrecv.py in sniff(*args, **kwargs)
#    1309     # type: (*Any, **Any) -> PacketList
#    1310     sniffer = AsyncSniffer()
# -> 1311     sniffer._run(*args, **kwargs)
#    1312     return cast(PacketList, sniffer.results)
#    1313
#
# ~\anaconda3\lib\site-packages\scapy\sendrecv.py in _run(self, count, store, offline, quiet, prn, lfilter, L2socket, timeout, opened_socket, stop_filter, iface, started_callback, session, session_kwargs, **karg)
#    1169             else:
#    1170                 iface = iface or conf.iface
# -> 1171                 sniff_sockets[_RL2(iface)(type=ETH_P_ALL, iface=iface,
#    1172                                           **karg)] = iface
#    1173
#
# ~\anaconda3\lib\site-packages\scapy\arch\libpcap.py in __init__(self, iface, type, promisc, filter, monitor)
#     479             else:
#     480                 self.promisc = conf.sniff_promisc
# --> 481             fd = open_pcap(
#     482                 iface, MTU, self.promisc, 100,
#     483                 monitor=monitor
#
# ~\anaconda3\lib\site-packages\scapy\arch\windows\__init__.py in open_pcap(iface, *args, **kargs)
#     768                 # interface state
#     769                 iface.setmonitor(kw_monitor)
# --> 770         return _orig_open_pcap(iface_network_name, *args, **kargs)
#     771     libpcap.open_pcap = open_pcap  # type: ignore
#     772
#
# ~\anaconda3\lib\site-packages\scapy\arch\libpcap.py in __init__(self, device, snaplen, promisc, to_ms, monitor)
#     336                 error = decode_locale_str(bytearray(self.errbuf).strip(b"\x00"))
#     337                 if error:
# --> 338                     raise OSError(error)
#     339
#     340             if WINDOWS:
#
# OSError: Error opening adapter: The filename, directory name, or volume label syntax is incorrect.  (123)
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
# Empty DataFrame
# Columns: [SSID, dBm_Signal, Channel, Crypto]
# Index: []
